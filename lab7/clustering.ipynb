# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv('breast-cancer-wisconsin-data_data.csv')
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0    ...          17.33           184.60      2019.0           0.16220
# 1    ...          23.41           158.80      1956.0           0.12380
# 2    ...          25.53           152.50      1709.0           0.14440
# 3    ...          26.50            98.87       567.7           0.20980
# 4    ...          16.67           152.20      1575.0           0.13740
# ..   ...            ...              ...         ...               ...
# 564  ...          26.40           166.10      2027.0           0.14100
# 565  ...          38.25           155.00      1731.0           0.11660
# 566  ...          34.12           126.70      1124.0           0.11390
# 567  ...          39.42           184.60      1821.0           0.16500
# 568  ...          30.37            59.16       268.6           0.08996
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0              0.66560           0.7119                0.2654          0.4601
# 1              0.18660           0.2416                0.1860          0.2750
# 2              0.42450           0.4504                0.2430          0.3613
# 3              0.86630           0.6869                0.2575          0.6638
# 4              0.20500           0.4000                0.1625          0.2364
# ..                 ...              ...                   ...             ...
# 564            0.21130           0.4107                0.2216          0.2060
# 565            0.19220           0.3215                0.1628          0.2572
# 566            0.30940           0.3403                0.1418          0.2218
# 567            0.86810           0.9387                0.2650          0.4087
# 568            0.06444           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst  Unnamed: 32
# 0                    0.11890          NaN
# 1                    0.08902          NaN
# 2                    0.08758          NaN
# 3                    0.17300          NaN
# 4                    0.07678          NaN
# ..                       ...          ...
# 564                  0.07115          NaN
# 565                  0.06637          NaN
# 566                  0.07820          NaN
# 567                  0.12400          NaN
# 568                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
data = data.drop(["id"], axis=1)
data = data.drop(["diagnosis"], axis=1)
data = data.drop(["Unnamed: 32"], axis=1)

# %%
import numpy as np 
plt.figure(figsize=(14,3))
line1 = np.array([2,1,1,2])
line2 = np.array([1,2,2,1])
plt.subplot(131)

plt.plot(line1, color="royalblue")
plt.plot(line2, color="lightcoral")
plt.title(np.corrcoef(line1, line2)[0,1], fontsize=18)

line1 = np.array([2,1,1,2])
line2 = np.array([1,2,2,3])
plt.subplot(132)
plt.plot(line1, color="royalblue")
plt.plot(line2, color="lightcoral")
plt.title(np.corrcoef(line1, line2)[0,1], fontsize=18)

line1 = np.array([2,1,1,2])
line2= 2*line1

plt.subplot(133)
plt.plot(line1, color="royalblue")
plt.plot(line2, color="lightcoral")
plt.title(np.corrcoef(line1, line2)[0,1], fontsize=18)
# Out:
# Text(0.5, 1.0, '1.0')

# %%
plt.figure(figsize=(15,10))
correlations = data.corr()
sns.heatmap(round(correlations,2), cmap="RdBu", annot=True,  annot_kws={"size":7}, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %%
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
from scipy.spatial.distance import squareform

plt.figure(figsize=(12,5))
dissimilarity = 1 - abs(correlations)
Z = linkage(squareform(dissimilarity), 'complete')

dendrogram(Z, labels=data.columns, orientation='top',leaf_rotation=90, leaf_font_size=8)
# Out:
# {'icoord': [[5.0, 5.0, 15.0, 15.0],
#   [35.0, 35.0, 45.0, 45.0],
#   [25.0, 25.0, 40.0, 40.0],
#   [65.0, 65.0, 75.0, 75.0],
#   [55.0, 55.0, 70.0, 70.0],
#   [95.0, 95.0, 105.0, 105.0],
#   [85.0, 85.0, 100.0, 100.0],
#   [62.5, 62.5, 92.5, 92.5],
#   [125.0, 125.0, 135.0, 135.0],
#   [115.0, 115.0, 130.0, 130.0],
#   [77.5, 77.5, 122.5, 122.5],
#   [32.5, 32.5, 100.0, 100.0],
#   [10.0, 10.0, 66.25, 66.25],
#   [145.0, 145.0, 155.0, 155.0],
#   [165.0, 165.0, 175.0, 175.0],
#   [150.0, 150.0, 170.0, 170.0],
#   [195.0, 195.0, 205.0, 205.0],
#   [185.0, 185.0, 200.0, 200.0],
#   [215.0, 215.0, 225.0, 225.0],
#   [192.5, 192.5, 220.0, 220.0],
#   [160.0, 160.0, 206.25, 206.25],
#   [235.0, 235.0, 245.0, 245.0],
#   [255.0, 255.0, 265.0, 265.0],
#   [240.0, 240.0, 260.0, 260.0],
#   [285.0, 285.0, 295.0, 295.0],
#   [275.0, 275.0, 290.0, 290.0],
#   [250.0, 250.0, 282.5, 282.5],
#   [183.125, 183.125, 266.25, 266.25],
#   [38.125, 38.125, 224.6875, 224.6875]],
#  'dcoord': [[0.0, 0.08795541115957894, 0.08795541115957894, 0.0],
#   [0.0, 0.02720632298392356, 0.02720632298392356, 0.0],
#   [0.0, 0.06234459304558426, 0.06234459304558426, 0.02720632298392356],
#   [0.0, 0.002144718506189136, 0.002144718506189136, 0.0],
#   [0.0, 0.01349319600860932, 0.01349319600860932, 0.002144718506189136],
#   [0.0, 0.006292083897051048, 0.006292083897051048, 0.0],
#   [0.0, 0.022421908593612927, 0.022421908593612927, 0.006292083897051048],
#   [0.01349319600860932,
#    0.05891754041395392,
#    0.05891754041395392,
#    0.022421908593612927],
#   [0.0, 0.07860897362114116, 0.07860897362114116, 0.0],
#   [0.0, 0.13867696636204896, 0.13867696636204896, 0.07860897362114116],
#   [0.05891754041395392,
#    0.3240127686939128,
#    0.3240127686939128,
#    0.13867696636204896],
#   [0.06234459304558426,
#    0.46893767217839544,
#    0.46893767217839544,
#    0.3240127686939128],
#   [0.08795541115957894,
#    0.8052014431657487,
#    0.8052014431657487,
#    0.46893767217839544],
#   [0.0, 0.19467580450563726, 0.19467580450563726, 0.0],
#   [0.0, 0.2327032207615639, 0.2327032207615639, 0.0],
#   [0.19467580450563726,
#    0.5006836314062331,
#    0.5006836314062331,
#    0.2327032207615639],
#   [0.0, 0.10773910122353147, 0.10773910122353147, 0.0],
#   [0.0, 0.18372475019997192, 0.18372475019997192, 0.10773910122353147],
#   [0.0, 0.3001742023562698, 0.3001742023562698, 0.0],
#   [0.18372475019997192,
#    0.5662789924098279,
#    0.5662789924098279,
#    0.3001742023562698],
#   [0.5006836314062331,
#    0.6659813161489161,
#    0.6659813161489161,
#    0.5662789924098279],
#   [0.0, 0.19673118233823206, 0.19673118233823206, 0.0],
#   [0.0, 0.22819600507615312, 0.22819600507615312, 0.0],
#   [0.19673118233823206,
#    0.388955860619277,
#    0.388955860619277,
#    0.22819600507615312],
#   [0.0, 0.5864938747921027, 0.5864938747921027, 0.0],
#   [0.0, 0.60275714735879, 0.60275714735879, 0.5864938747921027],
#   [0.388955860619277,
#    0.8050015355411809,
#    0.8050015355411809,
#    0.60275714735879],
#   [0.6659813161489161,
#    0.987338200434091,
#    0.987338200434091,
#    0.8050015355411809],
#   [0.8052014431657487,
#    0.9998890049273703,
#    0.9998890049273703,
#    0.987338200434091]],
#  'ivl': ['texture_mean',
#   'texture_worst',
#   'area_se',
#   'radius_se',
#   'perimeter_se',
#   'area_mean',
#   'radius_mean',
#   'perimeter_mean',
#   'area_worst',
#   'radius_worst',
#   'perimeter_worst',
#   'concave points_worst',
#   'concavity_mean',
#   'concave points_mean',
#   'smoothness_mean',
#   'smoothness_worst',
#   'fractal_dimension_mean',
#   'fractal_dimension_worst',
#   'compactness_mean',
#   'compactness_worst',
#   'concavity_worst',
#   'symmetry_mean',
#   'symmetry_worst',
#   'compactness_se',
#   'fractal_dimension_se',
#   'concavity_se',
#   'concave points_se',
#   'texture_se',
#   'smoothness_se',
#   'symmetry_se'],
#  'leaves': [1,
#   21,
#   13,
#   10,
#   12,
#   3,
#   0,
#   2,
#   23,
#   20,
#   22,
#   27,
#   6,
#   7,
#   4,
#   24,
#   9,
#   29,
#   5,
#   25,
#   26,
#   8,
#   28,
#   15,
#   19,
#   16,
#   17,
#   11,
#   14,
#   18],
#  'color_list': ['C1',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C0',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C0',
#   'C0',
#   'C0'],
#  'leaves_color_list': ['C1',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C5']}

# %%
treshold = 0.9
labels = fcluster(Z, treshold, criterion='distance')
labels
# Out:
# array([1, 1, 1, 1, 2, 2, 1, 1, 2, 2, 1, 3, 1, 1, 3, 3, 3, 3, 3, 3, 1, 1,
#        1, 1, 2, 2, 2, 1, 2, 2], dtype=int32)

# %%
import numpy as np 
labels_order = np.argsort(labels)
for idx, i in enumerate(data.columns[labels_order]):
    if idx ==0:
        clustered = pd.DataFrame(data[i])
    else:
        df_to_append = pd.DataFrame(data[i])
        clustered = pd.concat([clustered, df_to_append], axis=1)

# %%
plt.figure(figsize=(15,10))
correlations = clustered.corr()
sns.heatmap(round(correlations,2), cmap="RdBu", annot=True,  annot_kws={"size":7}, vmin=-1, vmax=1)
plt.title("Treshold: {}".format(treshold))
# Out:
# Text(0.5, 1.0, 'Treshold: 0.8')

# %%
plt.figure(figsize=(15,10))
for idx, t in enumerate(np.arange(0.2,1.1,0.1)): 
    plt.subplot(3,3,idx+1)
    labels = fcluster(Z, t, criterion='distance')
    labels_order = np.argsort(labels)
    for idx, i in enumerate(clustered.columns[labels_order]):
        if idx==0: 
            clustered = pd.DataFrame(data[i])
        else:
            df_to_append = pd.DataFrame(data[i])
            clustered = pd.concat([clustered, df_to_append], axis=1)

    correlations = clustered.corr()
    sns.heatmap(round(correlations,2), cmap="RdBu", annot=True,  annot_kws={"size":7}, vmin=-1, vmax=1)
    plt.title("Treshold: {}".format(t))

# %%
sns.clustermap(correlations, method="complete", cmap='RdBu', vmin=-1, vmax=1, annot=True, annot_kws={"size":7})

# %%
from numpy import unique
from numpy import where
from sklearn.cluster import AgglomerativeClustering
from matplotlib import pyplot 
from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import davies_bouldin_score

model = AgglomerativeClustering(n_clusters=6)
yhat = model.fit(Z)
yhat_2 = model.fit_predict(Z)
clusters = unique(yhat)

score_AGClustering_s = silhouette_score(Z, yhat.labels_, metric='euclidean')
score_AGClustering_ch = calinski_harabasz_score(Z, yhat.labels_)
score_AGClustering_db = davies_bouldin_score(Z, yhat.labels_)

print('Silhouette Score: ', score_AGClustering_s)
print('Calinski-Harabasz Score: ', score_AGClustering_ch)
print('Davies-Boulding Score: ', score_AGClustering_db)
# Out:
# Silhouette Score:  0.3319367684556613
# Calinski-Harabasz Score:  40.4137812199255
# Davies-Boulding Score:  0.8057116074886385
